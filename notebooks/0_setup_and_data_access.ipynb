# %% [markdown]
# <a href="https://colab.research.google.com/github/55766sufyan/aritifical_intelligence_chest_xray_pneumonia_semester5/blob/main/notebooks/0_setup_and_data_access.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
